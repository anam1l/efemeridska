# %% [markdown]
#  # **Keplerova jednačina**

# %% [markdown]
# Ana Milinković 241/2021

# %% [markdown]
# ___

# %% [markdown]
# U okviru ovog projektnog zadatka, koji je radjen kao projektni zadatak za kurs Efemeridska astronomija 1, prikazuju se rezultati Keplerove jednačine, dobijeni u radu "The dynamics of Kepler equation", V. Lanchares i I. L. Pérez Barrón,2003.
#
# Keplerova jednačina se koristi za opisivanje putanje planeta oko Sunca. Omogućava određivanje položaja planete u orbiti u određenom trenutku i omogućava nam da matematički objasnimo kretanja nebeskih tela.
#
# Keplerova jednačina se definiše:
# $$ E = M + e * sin(E) $$
#
# Gde je:
# - E - ekscentrična anomalija
# - M - srednja anomalija
# - e - ekscentricitet
#
# Keplerova jednačina je jedna od najpoznatijih nelinearnih jednačina. Postoje različite metode za rešavanje Keplerove jednačine poput: numeričke metode, serije rešenja, numeričke integracije, geometrijske metode...
# Neke od najpoznatijih metoda za rešavanje nelinearnih jednačina su metoda polovljenja intervala(binarna pretraga), metoda iterativnog poboljšanja (Newton-Raphson metoda, metoda sečice i metoda fiksne tačke),metode bazirane na konačnim razlikama, metoda regula-falsi, metoda optimizacije i druge.
#
# Prilikom rešavanja Keplerove nelinearne jednačine, koristiće se iterativna metoda za rešavanje nelinearne jednačine:
# $$ E_{n+1}= M + e*sin(E_n)$$
#
# Ekscentricitet je pojam koji se koristi kako bi se opisala karakteristika elipse ili orbite oko fokusa. Ekscentricitet je numerička vrednost koja meri "spuštenost" ili "nepravilnost" oblika elipse u odnosu na kružnicu.
# Ekscentricitet je uvek vrednost između 0 i 1. Ako je ekscentricitet jednak nuli, to znači da je elipsa zapravo kružnica (kada su oba fokusa u centru elipse). Kada je ekscentricitet jednak 1, to znači da je elipsa izdužena u jednom pravcu do tačke da postaje parabola, a kada je ekscentricitet veći od 1, elipsa postaje hiperbola.
#
# U radu su prikazane vrednosti dobijene nakon različitog broja iteracija i za različite početne uslove.
#
# Keplerova jednačina, koja matematički definiše odnos između ekscentrične anomalije (E), srednje anomalije (M) i ekscentriciteta (e), ima široku primenu u astrofizici i orbitalnoj mehanici.
#
# Keplerovu jednačinu predstavljamo pomoću formule:
# $$ F^{n}(e,E_0,M) = M + e*sin(E) $$
# gde je n broj iteracija, M srednja anomalija, e ekscentricitet i E eskcentrična anomalija.

# %% [markdown]
# ___

# %% [markdown]
# biblioteke:

# %%
import cmath
import numpy as np
import matplotlib.pyplot as plt
import astropy as ap
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## $$ F^{8}(e,E_0,M) $$

# %% [markdown]
# početni uslovi: E = -6$\pi$/2, broj iteracija = 8

# %%
def keplerova_jednacina(e,E0,M):
    E=E0
    for i in range(8):
        E1 = M + e*np.sin(E)
        E = E1
    return E1

M_osa = np.linspace(-np.pi,np.pi,600)
e_osa = np.linspace(-5,5,600)

E_mat = np.empty((len(e_osa),len(M_osa),))
e_duzina = len(e_osa)
M_duzina = len(M_osa)

for i in range(M_duzina):
    for j in range(e_duzina):
        E = keplerova_jednacina(e_osa[j],(-6*np.pi/2),M_osa[i])
        E_mat[i][j] = (E)

M,e = np.meshgrid(M_osa,e_osa)

plt.figure(dpi=100)
plt.pcolormesh(M_osa,e_osa,E_mat.T,cmap='viridis')
plt.colorbar()

plt.title('Keplerova jednacina')
plt.xlabel('M')
plt.ylabel('e')
plt.show()

# %% [markdown]
# Grafik prikazuje vrednosti srednje anomalije(E) nakon 8 iteracija, sa početnim uslovom $E = -3*\pi$, za različite uredjene parove (M,e).

# %% [markdown]
# ## $$ F^{16}(e,E_0,M) $$

# %% [markdown]
# početni uslovi: E =-$\pi$, broj iteracija = 16

# %%
def keplerova_jednacina(e,E0,M):
    E=E0
    for i in range(16):
        E1 = M + e*np.sin(E)
        E = E1
    return E1

M_osa = np.linspace(-np.pi,np.pi,600)
e_osa = np.linspace(-5,5,600)

E_mat = np.empty((len(e_osa),len(M_osa),))
e_duzina = len(e_osa)
M_duzina = len(M_osa)

for i in range(M_duzina):
    for j in range(e_duzina):
        E = keplerova_jednacina(e_osa[j],(-np.pi),M_osa[i])
        E_mat[i][j] = (E)

M,e = np.meshgrid(M_osa,e_osa)

plt.figure(dpi=100)
plt.pcolormesh(M_osa,e_osa,E_mat.T,cmap='viridis')
plt.colorbar()

plt.title('Keplerova jednacina')
plt.xlabel('M')
plt.ylabel('e')
plt.show()

# %% [markdown]
# Grafik prikazuje vrednosti srednje anomalije(E) nakon 16 iteracija, sa početnim uslovom $E = -\pi$, za različite uredjene parove (M,e).

# %% [markdown]
# ## $$ F^{32}(e,E_0,M) $$

# %% [markdown]
# početni uslovi: E = $\pi$, broj iteracija = 32

# %%
def keplerova_jednacina(e,E0,M):
    E=E0
    for i in range(32):
        E1 = M + e*np.sin(E)
        E = E1
    return E1

M_osa = np.linspace(-np.pi,np.pi,600)
e_osa = np.linspace(-5,5,600)

E_mat = np.empty((len(e_osa),len(M_osa),))
e_duzina = len(e_osa)
M_duzina = len(M_osa)

for i in range(M_duzina):
    for j in range(e_duzina):
        E = keplerova_jednacina(e_osa[j],(np.pi),M_osa[i])
        E_mat[i][j] = (E)

M,e = np.meshgrid(M_osa,e_osa)

plt.figure(dpi=100)
plt.pcolormesh(M_osa,e_osa,E_mat.T,cmap='viridis')
plt.colorbar()

plt.title('Keplerova jednacina')
plt.xlabel('M')
plt.ylabel('e')
plt.show()

# %% [markdown]
# Grafik prikazuje vrednosti srednje anomalije(E) nakon 32 iteracije, sa početnim uslovom $E = \pi$, za različite uredjene parove (M,e).

# %% [markdown]
# ___

# %% [markdown]
# Na osnovu grafika, možemo videti vertikalnu simetriju u odnosu na M = 0. Takodje, ako produžimo x osu možemo da zaključimo da je funkcija periodična sa $\pi$ periodom u odnosu na y osu.
#
# Povećavanjem broja iteracija, povećavamo vizuelnu složenost skupa vrednosti rešenja Keplerove jednačine.

# %% [markdown]
# ## Zumiranje bilo kog dela grafika za $ F^{32}(e,E_0,M) $ postiže se promenom granica na gridu

# %%
def keplerova_jednacina(e,E0,M):
    E=E0
    for i in range(32):
        E1 = M + e*np.sin(E)
        E = E1
    return E1

M_osa = np.linspace(1,1.2,600) #promena granica grida za M
e_osa = np.linspace(-3.2,-3,600) #promena granica grida za e

E_mat = np.empty((len(e_osa),len(M_osa),))
e_duzina = len(e_osa)
M_duzina = len(M_osa)

for i in range(M_duzina):
    for j in range(e_duzina):
        E = keplerova_jednacina(e_osa[j],(np.pi),M_osa[i])
        E_mat[i][j] = (E)

M,e = np.meshgrid(M_osa,e_osa)

plt.figure(dpi=100)
plt.pcolormesh(M_osa,e_osa,E_mat.T,cmap='viridis')
plt.colorbar()

plt.title('Keplerova jednacina')
plt.xlabel('M')
plt.ylabel('e')
plt.show()
